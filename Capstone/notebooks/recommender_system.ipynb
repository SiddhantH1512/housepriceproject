# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import warnings 
# %matplotlib inline

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/Users/siddhant/housepriceproject/Capstone/data/raw/appartments.csv").drop(22)
df.head()
# Out:
#                   PropertyName  \
# 0           Smartworld One DXP
# 1                    M3M Crown
# 2  Adani Brahma Samsara Vilasa
# 3                   Sobha City
# 4     Signature Global City 93
#
#                                      PropertySubName  \
# 0       2, 3, 4 BHK Apartment in Sector 113, Gurgaon
# 1          3, 4 BHK Apartment in Sector 111, Gurgaon
# 2  Land, 3, 4 BHK Independent Floor in Sector 63,...
# 3       2, 3, 4 BHK Apartment in Sector 108, Gurgaon
# 4    2, 3 BHK Independent Floor in Sector 93 Gurgaon
#
#                                      NearbyLocations  \
# 0  ['Bajghera Road', 'Palam Vihar Halt', 'DPSG Pa...
# 1  ['DPSG Palam Vihar Gurugram', 'The NorthCap Un...
# 2  ['AIPL Business Club Sector 62', 'Heritage Xpe...
# 3  ['The Shikshiyan School', 'WTC Plaza', 'Luxus ...
# 4  ['Pranavananda Int. School', 'DLF Site central...
#
#                                   LocationAdvantages  \
# 0  {'Bajghera Road': '800 Meter', 'Palam Vihar Ha...
# 1  {'DPSG Palam Vihar Gurugram': '1.4 Km', 'The N...
# 2  {'AIPL Business Club Sector 62': '2.7 Km', 'He...
# 3  {'The Shikshiyan School': '2.9 KM', 'WTC Plaza...
# 4  {'Pranavananda Int. School': '450 m', 'DLF Sit...
#
#                                                 Link  \
# 0  https://www.99acres.com/smartworld-one-dxp-sec...
# 1  https://www.99acres.com/m3m-crown-sector-111-g...
# 2  https://www.99acres.com/adani-brahma-samsara-v...
# 3  https://www.99acres.com/sobha-city-sector-108-...
# 4  https://www.99acres.com/signature-global-city-...
#
#                                         PriceDetails  \
# 0  {'2 BHK': {'building_type': 'Apartment', 'area...
# 1  {'3 BHK': {'building_type': 'Apartment', 'area...
# 2  {'3 BHK': {'building_type': 'Independent Floor...
# 3  {'2 BHK': {'building_type': 'Apartment', 'area...
# 4  {'2 BHK': {'building_type': 'Independent Floor...
#
#                                        TopFacilities
# 0  ['Swimming Pool', 'Salon', 'Restaurant', 'Spa'...
# 1  ['Bowling Alley', 'Mini Theatre', 'Manicured G...
# 2  ['Terrace Garden', 'Gazebo', 'Fountain', 'Amph...
# 3  ['Swimming Pool', 'Volley Ball Court', 'Aerobi...
# 4  ['Mini Theatre', 'Doctor on Call', 'Concierge ...

# %%
df.columns
# Out:
# Index(['PropertyName', 'PropertySubName', 'NearbyLocations',
#        'LocationAdvantages', 'Link', 'PriceDetails', 'TopFacilities'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 246 entries, 0 to 246
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PropertyName        246 non-null    object
#  1   PropertySubName     246 non-null    object
#  2   NearbyLocations     246 non-null    object
#  3   LocationAdvantages  246 non-null    object
#  4   Link                246 non-null    object
#  5   PriceDetails        246 non-null    object
#  6   TopFacilities       246 non-null    object
# dtypes: object(7)
# memory usage: 15.4+ KB

# %% [markdown]
# RECOMMENDER SYSTEM BASED ON TOP FACILITIES

# %%
df[["PropertyName", "TopFacilities"]]
# Out:
#                     PropertyName  \
# 0             Smartworld One DXP
# 1                      M3M Crown
# 2    Adani Brahma Samsara Vilasa
# 3                     Sobha City
# 4       Signature Global City 93
# ..                           ...
# 242         DLF Princeton Estate
# 243        Pyramid Urban Homes 2
# 244          Satya The Hermitage
# 245                  BPTP Spacio
# 246             SS The Coralwood
#
#                                          TopFacilities
# 0    ['Swimming Pool', 'Salon', 'Restaurant', 'Spa'...
# 1    ['Bowling Alley', 'Mini Theatre', 'Manicured G...
# 2    ['Terrace Garden', 'Gazebo', 'Fountain', 'Amph...
# 3    ['Swimming Pool', 'Volley Ball Court', 'Aerobi...
# 4    ['Mini Theatre', 'Doctor on Call', 'Concierge ...
# ..                                                 ...
# 242  ['Swimming Pool', 'Medical Centre', 'Laundry',...
# 243  ['Shopping Centre', 'Community Hall', '24x7 Se...
# 244  ['Bus Shelter', 'Swimming Pool', 'Business Lou...
# 245  ['Swimming Pool', 'Card Room', 'Piped Gas', 'P...
# 246  ['Swimming Pool', 'School', 'Solar Lighting', ...
#
# [246 rows x 2 columns]

# %%
df[["PropertyName", "TopFacilities"]]["TopFacilities"][0]
# Out:
# "['Swimming Pool', 'Salon', 'Restaurant', 'Spa', 'Cafeteria', 'Sun Deck', '24x7 Security', 'Club House', 'Gated Community']"

# %%
# LETS CONVERT THE STRINGS INTO ACTUAL LISTS
import re
def extract_list(s):
    return re.findall(r"'(.*?)'", s)

df['TopFacilities'] = df['TopFacilities'].apply(extract_list)

# %%
df['TopFacilities']
# Out:
# 0      [Swimming Pool, Salon, Restaurant, Spa, Cafete...
# 1      [Bowling Alley, Mini Theatre, Manicured Garden...
# 2      [Terrace Garden, Gazebo, Fountain, Amphitheatr...
# 3      [Swimming Pool, Volley Ball Court, Aerobics Ce...
# 4      [Mini Theatre, Doctor on Call, Concierge Servi...
#                              ...
# 242    [Swimming Pool, Medical Centre, Laundry, Salon...
# 243    [Shopping Centre, Community Hall, 24x7 Securit...
# 244    [Bus Shelter, Swimming Pool, Business Lounge, ...
# 245    [Swimming Pool, Card Room, Piped Gas, Pool Tab...
# 246    [Swimming Pool, School, Solar Lighting, Aerobi...
# Name: TopFacilities, Length: 246, dtype: object

# %%
# NOW LETS CONVERT THE LISTS BACK INTO STRINGS.
df["TopFacilities_str"] = [' '.join(x) for x in df["TopFacilities"]]

# %%
df["TopFacilities_str"]
# Out:
# 0      Swimming Pool Salon Restaurant Spa Cafeteria S...
# 1      Bowling Alley Mini Theatre Manicured Garden Sw...
# 2      Terrace Garden Gazebo Fountain Amphitheatre Pa...
# 3      Swimming Pool Volley Ball Court Aerobics Centr...
# 4      Mini Theatre Doctor on Call Concierge Service ...
#                              ...
# 242    Swimming Pool Medical Centre Laundry Salon Gro...
# 243    Shopping Centre Community Hall 24x7 Security G...
# 244    Bus Shelter Swimming Pool Business Lounge Read...
# 245    Swimming Pool Card Room Piped Gas Pool Table S...
# 246    Swimming Pool School Solar Lighting Aerobics C...
# Name: TopFacilities_str, Length: 246, dtype: object

# %%
# NOW LETS VECTORISE EACH OF THESE STRINGS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

tfidfvector = TfidfVectorizer(stop_words="english", ngram_range=(1, 2))
tfidf_matrix = tfidfvector.fit_transform(df["TopFacilities_str"])

# %%
# NOW SINCE THE STRINGS ARE VECTORISED, LETS FIND THE COSINE SIMILARITY BETWEEN A STRING WITH ALL OTHER STRINGS
cosinse_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
cosinse_sim.shape
# Out:
# (246, 246)

# %%
df["PropertyName"][0]
# Out:
# 'Smartworld One DXP'

# %%
def recommend_properties(property_name, cosinse_sim = cosinse_sim):
    # Take the index of the property name
    idx = df.index[df["PropertyName"] == property_name].tolist()[0]
    
    # Retrieving the cosine similarity score and index of the retrived index
    similarity_score = list(enumerate(cosinse_sim[idx]))
    
    # Sorting the similarity scores in a descending order (Each score and its index is a tuple in similarity_score)
    similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)
    
    # Retrieving the similarity scores of top 5 similar properties
    similarity_score = similarity_score[1:6]
    
    # Retrieving the index of these top similarity scores
    idx_sim = [i[0] for i in similarity_score]
    
    # Creating a dataframe of properties with their similarity scores
    recommendations_df = pd.DataFrame({
        'PropertyName': df['PropertyName'].iloc[idx_sim],
        'SimilarityScore': similarity_score
    })
    
    return recommendations_df

# %%
recommend_properties('Smartworld One DXP')
# Out:
#         PropertyName             SimilarityScore
# 11    DLF The Arbour     (11, 0.388850461994329)
# 154    India Rashtra   (153, 0.3459354538430299)
# 64   Ace Palm Floors    (63, 0.3278166625200139)
# 114       M3M Natura  (113, 0.31791768235666384)
# 116  Ireo City Plots  (115, 0.30214002412270297)

# %% [markdown]
# RECOMMENDER SYSTEM BASED ON PRICE DETAILS

# %%
df[["PropertyName", "PriceDetails"]]
# Out:
#                     PropertyName  \
# 0             Smartworld One DXP
# 1                      M3M Crown
# 2    Adani Brahma Samsara Vilasa
# 3                     Sobha City
# 4       Signature Global City 93
# ..                           ...
# 242         DLF Princeton Estate
# 243        Pyramid Urban Homes 2
# 244          Satya The Hermitage
# 245                  BPTP Spacio
# 246             SS The Coralwood
#
#                                           PriceDetails
# 0    {'2 BHK': {'building_type': 'Apartment', 'area...
# 1    {'3 BHK': {'building_type': 'Apartment', 'area...
# 2    {'3 BHK': {'building_type': 'Independent Floor...
# 3    {'2 BHK': {'building_type': 'Apartment', 'area...
# 4    {'2 BHK': {'building_type': 'Independent Floor...
# ..                                                 ...
# 242  {'2 BHK': {'building_type': 'Apartment', 'area...
# 243  {'1 BHK': {'building_type': 'Apartment', 'area...
# 244  {'2 BHK': {'building_type': 'Apartment', 'area...
# 245  {'2 BHK': {'building_type': 'Apartment', 'area...
# 246  {'2 BHK': {'building_type': 'Apartment', 'area...
#
# [246 rows x 2 columns]

# %%
import json

# Function to parse and extract the required features from the PriceDetails column
def refined_parse_modified_v2(detail_str):
    try:
        details = json.loads(detail_str.replace("'", "\""))
    except:
        return {}

    extracted = {}
    for bhk, detail in details.items():
        # Extract building type
        extracted[f'building type_{bhk}'] = detail.get('building_type')

        # Parsing area details
        area = detail.get('area', '')
        area_parts = area.split('-')
        if len(area_parts) == 1:
            try:
                value = float(area_parts[0].replace(',', '').replace(' sq.ft.', '').strip())
                extracted[f'area low {bhk}'] = value
                extracted[f'area high {bhk}'] = value
            except:
                extracted[f'area low {bhk}'] = None
                extracted[f'area high {bhk}'] = None
        elif len(area_parts) == 2:
            try:
                extracted[f'area low {bhk}'] = float(area_parts[0].replace(',', '').replace(' sq.ft.', '').strip())
                extracted[f'area high {bhk}'] = float(area_parts[1].replace(',', '').replace(' sq.ft.', '').strip())
            except:
                extracted[f'area low {bhk}'] = None
                extracted[f'area high {bhk}'] = None
        
        # Parsing price details
        price_range = detail.get('price-range', '')
        price_parts = price_range.split('-')
        if len(price_parts) == 2:
            try:
                extracted[f'price low {bhk}'] = float(price_parts[0].replace('₹', '').replace(' Cr', '').replace(' L', '').strip())
                extracted[f'price high {bhk}'] = float(price_parts[1].replace('₹', '').replace(' Cr', '').replace(' L', '').strip())
                if 'L' in price_parts[0]:
                    extracted[f'price low {bhk}'] /= 100
                if 'L' in price_parts[1]:
                    extracted[f'price high {bhk}'] /= 100
            except:
                extracted[f'price low {bhk}'] = None
                extracted[f'price high {bhk}'] = None

    return extracted
# Apply the refined parsing and generate the new DataFrame structure
data_refined = []

for _, row in df.iterrows():
    features = refined_parse_modified_v2(row['PriceDetails'])
    
    # Construct a new row for the transformed dataframe
    new_row = {'PropertyName': row['PropertyName']}
    
    # Populate the new row with extracted features
    for config in ['1 BHK', '2 BHK', '3 BHK', '4 BHK', '5 BHK', '6 BHK', '1 RK', 'Land']:
        new_row[f'building type_{config}'] = features.get(f'building type_{config}')
        new_row[f'area low {config}'] = features.get(f'area low {config}')
        new_row[f'area high {config}'] = features.get(f'area high {config}')
        new_row[f'price low {config}'] = features.get(f'price low {config}')
        new_row[f'price high {config}'] = features.get(f'price high {config}')
    
    data_refined.append(new_row)

df_final_refined_v2 = pd.DataFrame(data_refined).set_index('PropertyName')

# %%
df_final_refined_v2['building type_Land'] = df_final_refined_v2['building type_Land'].replace({'':'Land'})

# %%
df_final_refined_v2
# Out:
#                             building type_1 BHK  area low 1 BHK  \
# PropertyName
# Smartworld One DXP                         None             NaN
# M3M Crown                                  None             NaN
# Adani Brahma Samsara Vilasa                None             NaN
# Sobha City                                 None             NaN
# Signature Global City 93                   None             NaN
# ...                                         ...             ...
# DLF Princeton Estate                       None             NaN
# Pyramid Urban Homes 2                 Apartment           335.0
# Satya The Hermitage                        None             NaN
# BPTP Spacio                                None             NaN
# SS The Coralwood                           None             NaN
#
#                              area high 1 BHK  price low 1 BHK  \
# PropertyName
# Smartworld One DXP                       NaN              NaN
# M3M Crown                                NaN              NaN
# Adani Brahma Samsara Vilasa              NaN              NaN
# Sobha City                               NaN              NaN
# Signature Global City 93                 NaN              NaN
# ...                                      ...              ...
# DLF Princeton Estate                     NaN              NaN
# Pyramid Urban Homes 2                  398.0            23.45
# Satya The Hermitage                      NaN              NaN
# BPTP Spacio                              NaN              NaN
# SS The Coralwood                         NaN              NaN
#
#                              price high 1 BHK building type_2 BHK  \
# PropertyName
# Smartworld One DXP                        NaN           Apartment
# M3M Crown                                 NaN                None
# Adani Brahma Samsara Vilasa               NaN                None
# Sobha City                                NaN           Apartment
# Signature Global City 93                  NaN   Independent Floor
# ...                                       ...                 ...
# DLF Princeton Estate                      NaN           Apartment
# Pyramid Urban Homes 2                  0.2786           Apartment
# Satya The Hermitage                       NaN           Apartment
# BPTP Spacio                               NaN           Apartment
# SS The Coralwood                          NaN           Apartment
#
#                              area low 2 BHK  area high 2 BHK  price low 2 BHK  \
# PropertyName
# Smartworld One DXP                   1370.0           1370.0           2.0000
# M3M Crown                               NaN              NaN              NaN
# Adani Brahma Samsara Vilasa             NaN              NaN              NaN
# Sobha City                           1381.0           1692.0           1.5500
# Signature Global City 93              981.0           1118.0           0.9301
# ...                                     ...              ...              ...
# DLF Princeton Estate                  964.0            964.0              NaN
# Pyramid Urban Homes 2                 500.0            625.0              NaN
# Satya The Hermitage                  1450.0           1450.0              NaN
# BPTP Spacio                          1000.0           1079.0              NaN
# SS The Coralwood                     1320.0           1425.0              NaN
#
#                              price high 2 BHK  ... building type_1 RK  \
# PropertyName                                   ...
# Smartworld One DXP                       2.40  ...               None
# M3M Crown                                 NaN  ...               None
# Adani Brahma Samsara Vilasa               NaN  ...               None
# Sobha City                               3.21  ...               None
# Signature Global City 93                 1.06  ...               None
# ...                                       ...  ...                ...
# DLF Princeton Estate                      NaN  ...               None
# Pyramid Urban Homes 2                     NaN  ...               None
# Satya The Hermitage                       NaN  ...               None
# BPTP Spacio                               NaN  ...               None
# SS The Coralwood                          NaN  ...               None
#
#                              area low 1 RK  area high 1 RK  price low 1 RK  \
# PropertyName
# Smartworld One DXP                     NaN             NaN             NaN
# M3M Crown                              NaN             NaN             NaN
# Adani Brahma Samsara Vilasa            NaN             NaN             NaN
# Sobha City                             NaN             NaN             NaN
# Signature Global City 93               NaN             NaN             NaN
# ...                                    ...             ...             ...
# DLF Princeton Estate                   NaN             NaN             NaN
# Pyramid Urban Homes 2                  NaN             NaN             NaN
# Satya The Hermitage                    NaN             NaN             NaN
# BPTP Spacio                            NaN             NaN             NaN
# SS The Coralwood                       NaN             NaN             NaN
#
#                              price high 1 RK building type_Land  \
# PropertyName
# Smartworld One DXP                       NaN               None
# M3M Crown                                NaN               None
# Adani Brahma Samsara Vilasa              NaN               Land
# Sobha City                               NaN               None
# Signature Global City 93                 NaN               None
# ...                                      ...                ...
# DLF Princeton Estate                     NaN               None
# Pyramid Urban Homes 2                    NaN               None
# Satya The Hermitage                      NaN               None
# BPTP Spacio                              NaN               None
# SS The Coralwood                         NaN               None
#
#                              area low Land  area high Land  price low Land  \
# PropertyName
# Smartworld One DXP                     NaN             NaN             NaN
# M3M Crown                              NaN             NaN             NaN
# Adani Brahma Samsara Vilasa          500.0          4329.0            2.05
# Sobha City                             NaN             NaN             NaN
# Signature Global City 93               NaN             NaN             NaN
# ...                                    ...             ...             ...
# DLF Princeton Estate                   NaN             NaN             NaN
# Pyramid Urban Homes 2                  NaN             NaN             NaN
# Satya The Hermitage                    NaN             NaN             NaN
# BPTP Spacio                            NaN             NaN             NaN
# SS The Coralwood                       NaN             NaN             NaN
#
#                              price high Land
# PropertyName
# Smartworld One DXP                       NaN
# M3M Crown                                NaN
# Adani Brahma Samsara Vilasa            41.13
# Sobha City                               NaN
# Signature Global City 93                 NaN
# ...                                      ...
# DLF Princeton Estate                     NaN
# Pyramid Urban Homes 2                    NaN
# Satya The Hermitage                      NaN
# BPTP Spacio                              NaN
# SS The Coralwood                         NaN
#
# [246 rows x 40 columns]

# %%
categorical = df_final_refined_v2.select_dtypes(include="object").columns.to_list()

# %%
categorical
# Out:
# ['building type_1 BHK',
#  'building type_2 BHK',
#  'building type_3 BHK',
#  'building type_4 BHK',
#  'building type_5 BHK',
#  'building type_6 BHK',
#  'building type_1 RK',
#  'building type_Land']

# %%
ohe_df = pd.get_dummies(df_final_refined_v2, columns=categorical, drop_first=True)

# %%
ohe_df.fillna(0, inplace=True)

# %%
ohe_df
# Out:
#                              area low 1 BHK  area high 1 BHK  price low 1 BHK  \
# PropertyName
# Smartworld One DXP                      0.0              0.0             0.00
# M3M Crown                               0.0              0.0             0.00
# Adani Brahma Samsara Vilasa             0.0              0.0             0.00
# Sobha City                              0.0              0.0             0.00
# Signature Global City 93                0.0              0.0             0.00
# ...                                     ...              ...              ...
# DLF Princeton Estate                    0.0              0.0             0.00
# Pyramid Urban Homes 2                 335.0            398.0            23.45
# Satya The Hermitage                     0.0              0.0             0.00
# BPTP Spacio                             0.0              0.0             0.00
# SS The Coralwood                        0.0              0.0             0.00
#
#                              price high 1 BHK  area low 2 BHK  \
# PropertyName
# Smartworld One DXP                     0.0000          1370.0
# M3M Crown                              0.0000             0.0
# Adani Brahma Samsara Vilasa            0.0000             0.0
# Sobha City                             0.0000          1381.0
# Signature Global City 93               0.0000           981.0
# ...                                       ...             ...
# DLF Princeton Estate                   0.0000           964.0
# Pyramid Urban Homes 2                  0.2786           500.0
# Satya The Hermitage                    0.0000          1450.0
# BPTP Spacio                            0.0000          1000.0
# SS The Coralwood                       0.0000          1320.0
#
#                              area high 2 BHK  price low 2 BHK  \
# PropertyName
# Smartworld One DXP                    1370.0           2.0000
# M3M Crown                                0.0           0.0000
# Adani Brahma Samsara Vilasa              0.0           0.0000
# Sobha City                            1692.0           1.5500
# Signature Global City 93              1118.0           0.9301
# ...                                      ...              ...
# DLF Princeton Estate                   964.0           0.0000
# Pyramid Urban Homes 2                  625.0           0.0000
# Satya The Hermitage                   1450.0           0.0000
# BPTP Spacio                           1079.0           0.0000
# SS The Coralwood                      1425.0           0.0000
#
#                              price high 2 BHK  area low 3 BHK  \
# PropertyName
# Smartworld One DXP                       2.40          1850.0
# M3M Crown                                0.00          1605.0
# Adani Brahma Samsara Vilasa              0.00          1800.0
# Sobha City                               3.21          1711.0
# Signature Global City 93                 1.06          1235.0
# ...                                       ...             ...
# DLF Princeton Estate                     0.00          1127.0
# Pyramid Urban Homes 2                    0.00             0.0
# Satya The Hermitage                      0.00          1991.0
# BPTP Spacio                              0.00          1225.0
# SS The Coralwood                         0.00          1750.0
#
#                              area high 3 BHK  ...  \
# PropertyName                                  ...
# Smartworld One DXP                    2050.0  ...
# M3M Crown                             2170.0  ...
# Adani Brahma Samsara Vilasa           3150.0  ...
# Sobha City                            2343.0  ...
# Signature Global City 93              1530.0  ...
# ...                                      ...  ...
# DLF Princeton Estate                  1127.0  ...
# Pyramid Urban Homes 2                    0.0  ...
# Satya The Hermitage                   1991.0  ...
# BPTP Spacio                           1865.0  ...
# SS The Coralwood                      1890.0  ...
#
#                              building type_2 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                  False
# Sobha City                                                   False
# Signature Global City 93                                      True
# ...                                                            ...
# DLF Princeton Estate                                         False
# Pyramid Urban Homes 2                                        False
# Satya The Hermitage                                          False
# BPTP Spacio                                                  False
# SS The Coralwood                                             False
#
#                              building type_2 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                  False
# Sobha City                                                   False
# Signature Global City 93                                     False
# ...                                                            ...
# DLF Princeton Estate                                         False
# Pyramid Urban Homes 2                                        False
# Satya The Hermitage                                          False
# BPTP Spacio                                                  False
# SS The Coralwood                                             False
#
#                              building type_3 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                   True
# Sobha City                                                   False
# Signature Global City 93                                      True
# ...                                                            ...
# DLF Princeton Estate                                         False
# Pyramid Urban Homes 2                                        False
# Satya The Hermitage                                          False
# BPTP Spacio                                                  False
# SS The Coralwood                                             False
#
#                              building type_3 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                  False
# Sobha City                                                   False
# Signature Global City 93                                     False
# ...                                                            ...
# DLF Princeton Estate                                         False
# Pyramid Urban Homes 2                                        False
# Satya The Hermitage                                          False
# BPTP Spacio                                                  False
# SS The Coralwood                                             False
#
#                              building type_3 BHK_Villa  \
# PropertyName
# Smartworld One DXP                               False
# M3M Crown                                        False
# Adani Brahma Samsara Vilasa                      False
# Sobha City                                       False
# Signature Global City 93                         False
# ...                                                ...
# DLF Princeton Estate                             False
# Pyramid Urban Homes 2                            False
# Satya The Hermitage                              False
# BPTP Spacio                                      False
# SS The Coralwood                                 False
#
#                              building type_4 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                   True
# Sobha City                                                   False
# Signature Global City 93                                     False
# ...                                                            ...
# DLF Princeton Estate                                         False
# Pyramid Urban Homes 2                                        False
# Satya The Hermitage                                          False
# BPTP Spacio                                                  False
# SS The Coralwood                                             False
#
#                              building type_4 BHK_Villa  \
# PropertyName
# Smartworld One DXP                               False
# M3M Crown                                        False
# Adani Brahma Samsara Vilasa                      False
# Sobha City                                       False
# Signature Global City 93                         False
# ...                                                ...
# DLF Princeton Estate                             False
# Pyramid Urban Homes 2                            False
# Satya The Hermitage                              False
# BPTP Spacio                                      False
# SS The Coralwood                                 False
#
#                              building type_5 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                           False
# M3M Crown                                                    False
# Adani Brahma Samsara Vilasa                                  False
# Sobha City                                                   False
# Signature Global City 93                                     False
# ...                                                            ...
# DLF Princeton Estate                                         False
# Pyramid Urban Homes 2                                        False
# Satya The Hermitage                                          False
# BPTP Spacio                                                  False
# SS The Coralwood                                             False
#
#                              building type_5 BHK_Villa  \
# PropertyName
# Smartworld One DXP                               False
# M3M Crown                                        False
# Adani Brahma Samsara Vilasa                      False
# Sobha City                                       False
# Signature Global City 93                         False
# ...                                                ...
# DLF Princeton Estate                             False
# Pyramid Urban Homes 2                            False
# Satya The Hermitage                              False
# BPTP Spacio                                      False
# SS The Coralwood                                 False
#
#                              building type_6 BHK_Villa
# PropertyName
# Smartworld One DXP                               False
# M3M Crown                                        False
# Adani Brahma Samsara Vilasa                      False
# Sobha City                                       False
# Signature Global City 93                         False
# ...                                                ...
# DLF Princeton Estate                             False
# Pyramid Urban Homes 2                            False
# Satya The Hermitage                              False
# BPTP Spacio                                      False
# SS The Coralwood                                 False
#
# [246 rows x 43 columns]

# %%
ohe_df = ohe_df.astype(int)

# %%
ohe_df.sample(5)
# Out:
#                          area low 1 BHK  area high 1 BHK  price low 1 BHK  \
# PropertyName
# Signature Global Park                 0                0                0
# Birla Navya Avik                      0                0                0
# Ansals Shiva Som Valley               0                0                0
# Anant Raj Ashok Estate                0                0                0
# DLF The Crest                         0                0                0
#
#                          price high 1 BHK  area low 2 BHK  area high 2 BHK  \
# PropertyName
# Signature Global Park                   0             745              745
# Birla Navya Avik                        0               0                0
# Ansals Shiva Som Valley                 0               0                0
# Anant Raj Ashok Estate                  0               0                0
# DLF The Crest                           0            2246             2370
#
#                          price low 2 BHK  price high 2 BHK  area low 3 BHK  \
# PropertyName
# Signature Global Park                  0                 0            1081
# Birla Navya Avik                       0                 0            1225
# Ansals Shiva Som Valley                0                 0               0
# Anant Raj Ashok Estate                 0                 0               0
# DLF The Crest                          7                 8            2651
#
#                          area high 3 BHK  ...  \
# PropertyName                              ...
# Signature Global Park               1081  ...
# Birla Navya Avik                    1372  ...
# Ansals Shiva Som Valley                0  ...
# Anant Raj Ashok Estate                 0  ...
# DLF The Crest                       3518  ...
#
#                          building type_2 BHK_Independent Floor  \
# PropertyName
# Signature Global Park                                        1
# Birla Navya Avik                                             0
# Ansals Shiva Som Valley                                      0
# Anant Raj Ashok Estate                                       0
# DLF The Crest                                                0
#
#                          building type_2 BHK_Service Apartment  \
# PropertyName
# Signature Global Park                                        0
# Birla Navya Avik                                             0
# Ansals Shiva Som Valley                                      0
# Anant Raj Ashok Estate                                       0
# DLF The Crest                                                0
#
#                          building type_3 BHK_Independent Floor  \
# PropertyName
# Signature Global Park                                        1
# Birla Navya Avik                                             0
# Ansals Shiva Som Valley                                      0
# Anant Raj Ashok Estate                                       0
# DLF The Crest                                                0
#
#                          building type_3 BHK_Service Apartment  \
# PropertyName
# Signature Global Park                                        0
# Birla Navya Avik                                             0
# Ansals Shiva Som Valley                                      0
# Anant Raj Ashok Estate                                       0
# DLF The Crest                                                0
#
#                          building type_3 BHK_Villa  \
# PropertyName
# Signature Global Park                            0
# Birla Navya Avik                                 0
# Ansals Shiva Som Valley                          0
# Anant Raj Ashok Estate                           0
# DLF The Crest                                    0
#
#                          building type_4 BHK_Independent Floor  \
# PropertyName
# Signature Global Park                                        0
# Birla Navya Avik                                             0
# Ansals Shiva Som Valley                                      0
# Anant Raj Ashok Estate                                       0
# DLF The Crest                                                0
#
#                          building type_4 BHK_Villa  \
# PropertyName
# Signature Global Park                            0
# Birla Navya Avik                                 0
# Ansals Shiva Som Valley                          0
# Anant Raj Ashok Estate                           0
# DLF The Crest                                    0
#
#                          building type_5 BHK_Independent Floor  \
# PropertyName
# Signature Global Park                                        0
# Birla Navya Avik                                             0
# Ansals Shiva Som Valley                                      0
# Anant Raj Ashok Estate                                       0
# DLF The Crest                                                0
#
#                          building type_5 BHK_Villa  building type_6 BHK_Villa
# PropertyName
# Signature Global Park                            0                          0
# Birla Navya Avik                                 0                          0
# Ansals Shiva Som Valley                          0                          0
# Anant Raj Ashok Estate                           0                          0
# DLF The Crest                                    0                          0
#
# [5 rows x 43 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler  = StandardScaler()

scaler.set_output(transform="pandas")
scaled_df = scaler.fit_transform(ohe_df)

# %%
scaled_df.head()
# Out:
#                              area low 1 BHK  area high 1 BHK  price low 1 BHK  \
# PropertyName
# Smartworld One DXP                -0.252236        -0.169557        -0.102483
# M3M Crown                         -0.252236        -0.169557        -0.102483
# Adani Brahma Samsara Vilasa       -0.252236        -0.169557        -0.102483
# Sobha City                        -0.252236        -0.169557        -0.102483
# Signature Global City 93          -0.252236        -0.169557        -0.102483
#
#                              price high 1 BHK  area low 2 BHK  \
# PropertyName
# Smartworld One DXP                  -0.077568        1.223655
# M3M Crown                           -0.077568       -0.893477
# Adani Brahma Samsara Vilasa         -0.077568       -0.893477
# Sobha City                          -0.077568        1.240653
# Signature Global City 93            -0.077568        0.622513
#
#                              area high 2 BHK  price low 2 BHK  \
# PropertyName
# Smartworld One DXP                  1.020205        -0.167063
# M3M Crown                          -0.896604        -0.277097
# Adani Brahma Samsara Vilasa        -0.896604        -0.277097
# Sobha City                          1.470725        -0.222080
# Signature Global City 93            0.667624        -0.277097
#
#                              price high 2 BHK  area low 3 BHK  \
# PropertyName
# Smartworld One DXP                   1.037026        0.553850
# M3M Crown                           -0.316334        0.293146
# Adani Brahma Samsara Vilasa         -0.316334        0.500645
# Sobha City                           1.713706        0.405941
# Signature Global City 93             0.360346       -0.100570
#
#                              area high 3 BHK  ...  \
# PropertyName                                  ...
# Smartworld One DXP                  0.370901  ...
# M3M Crown                           0.472786  ...
# Adani Brahma Samsara Vilasa         1.304848  ...
# Sobha City                          0.619670  ...
# Signature Global City 93           -0.070602  ...
#
#                              building type_2 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.289310
# M3M Crown                                                -0.289310
# Adani Brahma Samsara Vilasa                              -0.289310
# Sobha City                                               -0.289310
# Signature Global City 93                                  3.456497
#
#                              building type_2 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                       -0.063888
# M3M Crown                                                -0.063888
# Adani Brahma Samsara Vilasa                              -0.063888
# Sobha City                                               -0.063888
# Signature Global City 93                                 -0.063888
#
#                              building type_3 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.372678
# M3M Crown                                                -0.372678
# Adani Brahma Samsara Vilasa                               2.683282
# Sobha City                                               -0.372678
# Signature Global City 93                                  2.683282
#
#                              building type_3 BHK_Service Apartment  \
# PropertyName
# Smartworld One DXP                                       -0.063888
# M3M Crown                                                -0.063888
# Adani Brahma Samsara Vilasa                              -0.063888
# Sobha City                                               -0.063888
# Signature Global City 93                                 -0.063888
#
#                              building type_3 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.171139
# M3M Crown                                    -0.171139
# Adani Brahma Samsara Vilasa                  -0.171139
# Sobha City                                   -0.171139
# Signature Global City 93                     -0.171139
#
#                              building type_4 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.254824
# M3M Crown                                                -0.254824
# Adani Brahma Samsara Vilasa                               3.924283
# Sobha City                                               -0.254824
# Signature Global City 93                                 -0.254824
#
#                              building type_4 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.236208
# M3M Crown                                    -0.236208
# Adani Brahma Samsara Vilasa                  -0.236208
# Sobha City                                   -0.236208
# Signature Global City 93                     -0.236208
#
#                              building type_5 BHK_Independent Floor  \
# PropertyName
# Smartworld One DXP                                       -0.111111
# M3M Crown                                                -0.111111
# Adani Brahma Samsara Vilasa                              -0.111111
# Sobha City                                               -0.111111
# Signature Global City 93                                 -0.111111
#
#                              building type_5 BHK_Villa  \
# PropertyName
# Smartworld One DXP                           -0.216353
# M3M Crown                                    -0.216353
# Adani Brahma Samsara Vilasa                  -0.216353
# Sobha City                                   -0.216353
# Signature Global City 93                     -0.216353
#
#                              building type_6 BHK_Villa
# PropertyName
# Smartworld One DXP                           -0.063888
# M3M Crown                                    -0.063888
# Adani Brahma Samsara Vilasa                  -0.063888
# Sobha City                                   -0.063888
# Signature Global City 93                     -0.063888
#
# [5 rows x 43 columns]

# %%
cosinse_sim2 = cosine_similarity(scaled_df)

# %%
cosinse_sim2.shape
# Out:
# (246, 246)

# %%
def recommend_properties_with_scores(property_name, top_n=5):
    
    # Get the similarity scores for the property using its name as the index
    sim_scores = list(enumerate(cosinse_sim2[scaled_df.index.get_loc(property_name)]))
    
    # Sort properties based on the similarity scores
    sorted_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the indices and scores of the top_n most similar properties
    top_indices = [i[0] for i in sorted_scores[1:top_n+1]]
    top_scores = [i[1] for i in sorted_scores[1:top_n+1]]
    
    # Retrieve the names of the top properties using the indices
    top_properties = scaled_df.index[top_indices].tolist()
    
    # Create a dataframe with the results
    recommendations_df = pd.DataFrame({
        'PropertyName': top_properties,
        'SimilarityScore': top_scores
    })
    
    return recommendations_df

# Test the recommender function using a property name
recommend_properties_with_scores('M3M Golf Hills')
# Out:
#               PropertyName  SimilarityScore
# 0           Unitech Escape         0.955051
# 1              M3M Capital         0.949478
# 2  AIPL The Peaceful Homes         0.922306
# 3    Vatika Seven Elements         0.921685
# 4               BPTP Terra         0.920803

# %% [markdown]
# RECOMMENDATION SYSTEM BASED ON LOCATION ADVANTAGE

# %%
df[["PropertyName", "LocationAdvantages"]]
# Out:
#                     PropertyName  \
# 0             Smartworld One DXP
# 1                      M3M Crown
# 2    Adani Brahma Samsara Vilasa
# 3                     Sobha City
# 4       Signature Global City 93
# ..                           ...
# 242         DLF Princeton Estate
# 243        Pyramid Urban Homes 2
# 244          Satya The Hermitage
# 245                  BPTP Spacio
# 246             SS The Coralwood
#
#                                     LocationAdvantages
# 0    {'Bajghera Road': '800 Meter', 'Palam Vihar Ha...
# 1    {'DPSG Palam Vihar Gurugram': '1.4 Km', 'The N...
# 2    {'AIPL Business Club Sector 62': '2.7 Km', 'He...
# 3    {'The Shikshiyan School': '2.9 KM', 'WTC Plaza...
# 4    {'Pranavananda Int. School': '450 m', 'DLF Sit...
# ..                                                 ...
# 242  {'Sector 42-43 Metro Station': '1.8 Km', 'Para...
# 243  {'Aarvy Healthcare Super Speciality': '1.8 KM'...
# 244  {'Dwarka Expressway': '1.2 Km', 'S N Internati...
# 245  {'Suncity School': '0.2 Km', 'Gurugram Road': ...
# 246  {'Sector 84 Road': '600 Meter', 'Delhi Public ...
#
# [246 rows x 2 columns]

# %%
# CONVERTING KMS TO METERS
def distance_mts(distance_str):
    try:
        if 'Km' in distance_str or 'KM' in distance_str:
            return float(distance_str.split()[0]) * 1000
        elif 'Meter' in distance_str or 'meter' in distance_str:
            return float(distance_str.split()[0])
        else:
            return None
    except:
        return None

# %%
df["LocationAdvantages"][0]
# Out:
# "{'Bajghera Road': '800 Meter', 'Palam Vihar Halt': '2.5 KM', 'DPSG Palam Vihar': '3.1 KM', 'Park Hospital': '3.1 KM', 'Gurgaon Railway Station': '4.9 KM', 'The NorthCap University': '5.4 KM', 'Dwarka Expy': '1.2 KM', 'Hyatt Place Gurgaon Udyog Vihar': '7.7 KM', 'Dwarka Sector 21, Metro Station': '7.2 KM', 'Pacific D21 Mall': '7.4 KM', 'Indira Gandhi International Airport': '14.7 KM', 'Hamoni Golf Camp': '6.2 KM', 'Fun N Food Waterpark': '8.8 KM', 'Accenture DDC5': '9 KM'}"

# %%
import ast
location_matrix = {}
locations_list = []
for index, row in df.iterrows():
    location_advantages = ast.literal_eval(row['LocationAdvantages'])
    if location_advantages:
        # Check if the dictionary is not empty
        distances = {}
        for location, distance in location_advantages.items():
            location = location.strip()
            if location in ['4D Square Mall','4 D SQUARE MALL','4 D Mall' ,'4d Square Mall','4 D Square Mall']:
                distances['4D Square Mall'] = distance_mts(distance)
            elif location in ["Sunrise cricket Ground", "Sunrise Cricket Ground"]:
                distances['Sunrise cricket Ground'] = distance_mts(distance)
            elif location in ["Gandhinagar Capital Railway Station", "Gandhinagar Railway Station"]:
                distances['Gandhinagar Railway Station'] = distance_mts(distance)
            elif location in ["Apparel Park Metro Station", "Apparel Park"]:
                distances['Apparel Park Metro Station'] = distance_mts(distance)
            elif location in ["Sabarmati Junction", "Sabarmati Jn Railway Station"]:
                distances['Sabarmati Junction'] = distance_mts(distance)
            elif location in ["Science City Circle", "Science City Nature Park", "SAL College of Engineering", "Science City Aquarium", "SAL Engineering",
    "Science City Ahmedabad", "SAL College",'Science City and Park','SAL Institute']:
                distances['Science City'] = distance_mts(distance)
            elif location in ["Divine Kids Pre-School", "Divine Life Intl School", "Divine Kids Preschool"]:
                distances['Divine Kids Pre-School'] = distance_mts(distance)
            elif location in ["Chandkhera Railway Station", "Chandkhera Road railway station"]:
                distances['Chandkhera Railway Station'] = distance_mts(distance)
            elif location in ["Fun Blast Ahmedabad", "Fun Blast - SBR", "Fun Blast"]:
                distances['Fun Blast Ahmedabad'] = distance_mts(distance)
            elif location in ["NH 48", "NH48"]:
                distances['NH 48'] = distance_mts(distance)
            elif location in ["PVR Acropolis", "The Acropolis", "Acropolis Mall", "The Acropolis Mall", "PVR Acropollis"]:
                distances['PVR Acropolis'] = distance_mts(distance)
            elif location in ["Motera Stadium metro station", "Motera Metro station", "Motera Stadium Metro Station", "Motera Metro Station"]:
                distances['Motera Stadium metro station'] = distance_mts(distance)
            elif location in ["Wyndham Ahmedabad Shela", "Wyndham Ahmedabad"]:
                distances['Wyndham Ahmedabad Shela'] = distance_mts(distance)
            elif location in ["Gift City", "GIFT City"]:
                distances['Gift City'] = distance_mts(distance)
            elif location in ["Shalby Multi-Specialty Hospitals", "Shalby Multi-Specialty Hospital", "Shalby Hospital", "Shalby hospital"]:
                distances['Shalby Multi-Specialty Hospitals'] = distance_mts(distance)
            elif location in ["Ambli Road", "Ambli Lake"]:
                distances['Ambli Road'] = distance_mts(distance)
            elif location in ["SG Highway", "Sarkhej - Gandhinagar Hwy", "S.G. Highway", "Sarkhej Gandhinagar Highway", "S G Highway", "S. G. Highway"]:
                distances['SG Highway'] = distance_mts(distance)
            elif location in ["Taj Skyline", "Taj Skyline, Ahmedabad"]:
                distances['Taj Skyline'] = distance_mts(distance)
            elif location in ["Apollo Pharmacy", "Apollo Hospital", "APOLLO HOSPITAL"]:
                distances['Apollo Hospital'] = distance_mts(distance)
            elif location in ["CIMS Hospital", "Marengo CIMS Hospital", "CIMS hospital"]:
                distances['CIMS Hospital'] = distance_mts(distance)
            elif location in ["Sardar Vallabhbhai Patel Stadium", "SVP Stadium", "Sardar Vallabhbhai Patel", "Sardar Patel Stadium"]:
                distances['SVP Stadium'] = distance_mts(distance)
            elif location in ["Nirma University", "NIRMA UNIVERSITY", "Institute Of Science, Nirma University"]:
                distances['Nirma University'] = distance_mts(distance)
            elif location in ["Thaltej Metro Station", "Thaltej"]:
                distances['Thaltej Metro Station'] = distance_mts(distance)
            elif location in ["Narendra Modi Stadium", "Motera Stadium", "MODI STADIUM", "Motera stadium"]:
                distances['Narendra Modi Stadium'] = distance_mts(distance)
            elif location in ["NH147", "NH 147", "NH147, Gujarat", "NH147, Sarkhej", "NH147, Ahmedabad"]:
                distances['NH 147'] = distance_mts(distance)
            elif location in ["International Airport", "Vallabhbhai Patel Intl Airport", "SVP International Airport", "Ahmedabad Domestic Airport",
    "Ahmedabad International Airport T2", "Sardar Vallabhbhai Patel Intl Airport", "Airport", "Ahmedabad Airport",
    "Sardar Vallabhbhai Patel Airport", "SVP Intl Airport", "International airport", "International Airport Ahmedabad",
    "Ahmedabad Int Airport T2", "The Ummed Ahmedabad Airport", "Ahmedabad Intl Airport T2", "Sardar Vallabhbhai Patel Int",
    "Ahmedabad domestic airport", "SVPI Airport"]:
                distances['SVP International Airport'] = distance_mts(distance)
            elif location in ["Sardar Patel Ring Road", "Sardar Patel Ring Rd"]:
                distances['Sardar Patel Ring Road'] = distance_mts(distance)
            elif location in ["TRP Mall Bopal", "TRP Mall"]:
                distances['TRP Mall'] = distance_mts(distance)
            elif location in ["Goraghuma Railway Station", "Goraghuma"]:
                distances['Goraghuma Railway Station'] = distance_mts(distance)
            else: 
                distances[location] = distance_mts(distance)
            locations_list.append(location)
        location_matrix[index] = distances
#         print(distances)
    else:
        location_matrix[index] = {'':''}
        # If the dictionary is empty, you can choose to handle it as needed
        # For example, you can add a default value or skip it
       

# Convert the dictionary to a DataFrame
location_df = pd.DataFrame.from_dict(location_matrix, orient='index')
location_df.head()
# Out:
#     Bajghera Road  Palam Vihar Halt  DPSG Palam Vihar  Park Hospital  \
# 0           800.0            2500.0            3100.0         3100.0
# 25          550.0               NaN               NaN            NaN
# 37         5300.0               NaN               NaN            NaN
# 69         1500.0               NaN               NaN            NaN
# 9             NaN               NaN               NaN         5500.0
#
#     Gurgaon Railway Station  The NorthCap University  Dwarka Expy  \
# 0                    4900.0                   5400.0       1200.0
# 25                      NaN                   6700.0       3800.0
# 37                   2500.0                   8800.0          NaN
# 69                   6500.0                   6700.0       5100.0
# 9                       NaN                      NaN          NaN
#
#     Hyatt Place Gurgaon Udyog Vihar  Dwarka Sector 21, Metro Station  \
# 0                            7700.0                           7200.0
# 25                              NaN                              NaN
# 37                              NaN                              NaN
# 69                              NaN                              NaN
# 9                               NaN                              NaN
#
#     Pacific D21 Mall  ...  MCC Cricket Ground Dhankot  \
# 0             7400.0  ...                         NaN
# 25            7500.0  ...                         NaN
# 37               NaN  ...                         NaN
# 69            8200.0  ...                         NaN
# 9                NaN  ...                         NaN
#
#     The Shri Ram School Aravali  Taj City Centre Gurugram  \
# 0                           NaN                       NaN
# 25                          NaN                       NaN
# 37                          NaN                       NaN
# 69                          NaN                       NaN
# 9                           NaN                       NaN
#
#     Minda Industries  Corporate Office  Rampura Flyover, Naurangpur Rd  \
# 0                                  NaN                             NaN
# 25                                 NaN                             NaN
# 37                                 NaN                             NaN
# 69                                 NaN                             NaN
# 9                                  NaN                             NaN
#
#     Manesar toll plaza - Kherki Daula  Imt Manesar, Gurugram  Holiday Inn  \
# 0                                 NaN                    NaN          NaN
# 25                                NaN                    NaN          NaN
# 37                                NaN                    NaN          NaN
# 69                                NaN                    NaN          NaN
# 9                                 NaN                    NaN          NaN
#
#     Sector 84 Road  Skyview Corporate Park
# 0              NaN                     NaN
# 25             NaN                     NaN
# 37             NaN                     NaN
# 69             NaN                     NaN
# 9              NaN                     NaN
#
# [5 rows x 1068 columns]

# %%
locations_list = []
for i, value in location_matrix.items():
    locations_list.extend(value.keys())

# %%
words_list = [
    ["Gandhinagar Capital Railway Station", "Gandhinagar Railway Station"],
    ["Sunrise cricket Ground", "Sunrise Cricket Ground"],
    ["Apparel Park Metro Station", "Apparel Park"],
    ["Sabarmati Junction", "Sabarmati Jn Railway Station"],
    ["Science City Circle", "Science City Nature Park", "SAL College of Engineering", "Science City Aquarium", "SAL Engineering",
    "Science City Ahmedabad", "SAL College"],
    ["Divine Kids Pre-School", "Divine Life Intl School", "Divine Kids Preschool"],
    ["Chandkhera Railway Station", "Chandkhera Road railway station"],
    ["Fun Blast Ahmedabad", "Fun Blast - SBR", "Fun Blast"],
    ["NH 48", "NH48"],
    ["PVR Acropolis", "The Acropolis", "Acropolis Mall", "The Acropolis Mall", "PVR Acropollis"],
    ["Motera Stadium metro station", "Motera Metro station", "Motera Stadium Metro Station", "Motera Metro Station"],
    ["Wyndham Ahmedabad Shela", "Wyndham Ahmedabad"],
    ["Gift City", "GIFT City"],
    ["Shalby Multi-Specialty Hospitals", "Shalby Multi-Specialty Hospital", "Shalby Hospital", "Shalby hospital"],
    ["Ambli Road", "Ambli Lake"],
    ["SG Highway", "Sarkhej - Gandhinagar Hwy", "S.G. Highway", "Sarkhej Gandhinagar Highway", "S G Highway", "S. G. Highway"],
    ["Taj Skyline", "Taj Skyline, Ahmedabad"],
    ["Apollo Pharmacy", "Apollo Hospital", "APOLLO HOSPITAL"],
    ["CIMS Hospital", "Marengo CIMS Hospital", "CIMS hospital"],
    ["Sardar Vallabhbhai Patel Stadium", "SVP Stadium", "Sardar Vallabhbhai Patel", "Sardar Patel Stadium"],
    ["Nirma University", "NIRMA UNIVERSITY", "Institute Of Science, Nirma University"],
    ["Thaltej Metro Station", "Thaltej"],
    ["Narendra Modi Stadium", "Motera Stadium", "MODI STADIUM", "Motera stadium"],
    ["NH147", "NH 147", "NH147, Gujarat", "NH147, Sarkhej", "NH147, Ahmedabad"],
    ["International Airport", "Vallabhbhai Patel Intl Airport", "SVP International Airport", "Ahmedabad Domestic Airport",
    "Ahmedabad International Airport T2", "Sardar Vallabhbhai Patel Intl Airport", "Airport", "Ahmedabad Airport",
    "Sardar Vallabhbhai Patel Airport", "SVP Intl Airport", "International airport", "International Airport Ahmedabad",
    "Ahmedabad Int Airport T2", "The Ummed Ahmedabad Airport", "Ahmedabad Intl Airport T2", "Sardar Vallabhbhai Patel Int",
    "Ahmedabad domestic airport", "SVPI Airport"],
    ["Sardar Patel Ring Road", "Sardar Patel Ring Rd"],
    ["TRP Mall Bopal", "TRP Mall"],
    ["Goraghuma Railway Station", "Goraghuma"]
]

# %%
from collections import Counter

counts = Counter(locations_list)
locations_dic = dict(counts)
len(locations_dic)
# Out:
# 1068

# %%
top_locations = []
for key, value in locations_dic.items():
    if value > 1:
        top_locations.append(key)
len(top_locations)
# Out:
# 337

# %%
remove_locations = ['ATM UNION BANK OF INDIA', 'HP Petrol Pump', 'State Bank of India', 'Axis Bank ATM', 'Axis Bank, Adventure Park',
                   'ICICI BANK ATM', 'HP PETROL PUMP.Metro', 'Super Market', 'Kotak Mahindra Bank ATM', 'Railway Station',
                   'Auda Garden', 'Sanand Station', 'State Bank ATM', 'Bank Of Baroda', 'AMTS Bus Stop', 'BRTS Bus Stop',
                   'Corporation Bank ATM', 'Sanand', 'Metro Station', 'ICICI Bank ATM', 'South Indian Bank ATM',
                   'Indian Oil Petrol Pump', 'Dhaval Medical Store', 'Sanand Railway Station', 'Chandlodiya Station',
                   'AUDA Garden', 'HDFC bank ATM', 'BOB ATM', 'Indusind Bank', 'HDFC Bank', 'Bharat petrol pump', 'SBI',
                   'Post Office', 'Kalupur Co-operative Bank', 'Bharat Petroleum', 'Canara Bank', 'Indian Oil',
                   'ICICI Bank -Motera', 'BRTS', 'Cinemas', 'Malls', 'Hospitals', 'International Schools',
                   'International Stadium', 'PVR Cinema', 'Sabarmati', 'Motera', 'Royal Chemist', 'Hospital', 'Bank',
                   'Bus Station', 'School/College', 'Sarkhej', 'Bank of India', 'PNB ATM', 'Axis bank ATM',
                   'Bank of India ATM', 'Central bank of India ATM', 'GSC Bank, Gota', 'Maninagar', 'Sardar Vallabhbhai',
                   'SBI ATM', 'Pallav', 'Changodar', 'GSC Bank Gota Branch', 'Nilesha', 'Asarva', 'D MART',
                   'Central bank of india ATM', 'Indian Bank', 'Union Bank', 'Union Bank with ATM', 'Yes bank ATM',
                   'D-Mart', 'Cng Petrol Pump', 'Bank Of India', 'Petrol Pump', 'Ring Road', 'Adalaj', 'Indian Bank ATM',
                   'Khodiyar', 'Sanathal', 'Essar Petrol Pump', 'IDBI','']

# %%
display_locations = [item for item in top_locations if item not in remove_locations]
len(display_locations)
# Out:
# 333

# %%
location_df.shape
# Out:
# (246, 1068)

# %%
location_df = location_df.set_index(keys=df["PropertyName"])
location_df.head()
# Out:
#                              Bajghera Road  Palam Vihar Halt  \
# PropertyName
# Smartworld One DXP                   800.0            2500.0
# M3M Crown                            550.0               NaN
# Adani Brahma Samsara Vilasa         5300.0               NaN
# Sobha City                          1500.0               NaN
# Signature Global City 93               NaN               NaN
#
#                              DPSG Palam Vihar  Park Hospital  \
# PropertyName
# Smartworld One DXP                     3100.0         3100.0
# M3M Crown                                 NaN            NaN
# Adani Brahma Samsara Vilasa               NaN            NaN
# Sobha City                                NaN            NaN
# Signature Global City 93                  NaN         5500.0
#
#                              Gurgaon Railway Station  The NorthCap University  \
# PropertyName
# Smartworld One DXP                            4900.0                   5400.0
# M3M Crown                                        NaN                   6700.0
# Adani Brahma Samsara Vilasa                   2500.0                   8800.0
# Sobha City                                    6500.0                   6700.0
# Signature Global City 93                         NaN                      NaN
#
#                              Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# PropertyName
# Smartworld One DXP                1200.0                           7700.0
# M3M Crown                         3800.0                              NaN
# Adani Brahma Samsara Vilasa          NaN                              NaN
# Sobha City                        5100.0                              NaN
# Signature Global City 93             NaN                              NaN
#
#                              Dwarka Sector 21, Metro Station  \
# PropertyName
# Smartworld One DXP                                    7200.0
# M3M Crown                                                NaN
# Adani Brahma Samsara Vilasa                              NaN
# Sobha City                                               NaN
# Signature Global City 93                                 NaN
#
#                              Pacific D21 Mall  ...  \
# PropertyName                                   ...
# Smartworld One DXP                     7400.0  ...
# M3M Crown                              7500.0  ...
# Adani Brahma Samsara Vilasa               NaN  ...
# Sobha City                             8200.0  ...
# Signature Global City 93                  NaN  ...
#
#                              MCC Cricket Ground Dhankot  \
# PropertyName
# Smartworld One DXP                                  NaN
# M3M Crown                                           NaN
# Adani Brahma Samsara Vilasa                         NaN
# Sobha City                                          NaN
# Signature Global City 93                            NaN
#
#                              The Shri Ram School Aravali  \
# PropertyName
# Smartworld One DXP                                   NaN
# M3M Crown                                            NaN
# Adani Brahma Samsara Vilasa                          NaN
# Sobha City                                           NaN
# Signature Global City 93                             NaN
#
#                              Taj City Centre Gurugram  \
# PropertyName
# Smartworld One DXP                                NaN
# M3M Crown                                         NaN
# Adani Brahma Samsara Vilasa                       NaN
# Sobha City                                        NaN
# Signature Global City 93                          NaN
#
#                              Minda Industries  Corporate Office  \
# PropertyName
# Smartworld One DXP                                          NaN
# M3M Crown                                                   NaN
# Adani Brahma Samsara Vilasa                                 NaN
# Sobha City                                                  NaN
# Signature Global City 93                                    NaN
#
#                              Rampura Flyover, Naurangpur Rd  \
# PropertyName
# Smartworld One DXP                                      NaN
# M3M Crown                                               NaN
# Adani Brahma Samsara Vilasa                             NaN
# Sobha City                                              NaN
# Signature Global City 93                                NaN
#
#                              Manesar toll plaza - Kherki Daula  \
# PropertyName
# Smartworld One DXP                                         NaN
# M3M Crown                                                  NaN
# Adani Brahma Samsara Vilasa                                NaN
# Sobha City                                                 NaN
# Signature Global City 93                                   NaN
#
#                              Imt Manesar, Gurugram  Holiday Inn  \
# PropertyName
# Smartworld One DXP                             NaN          NaN
# M3M Crown                                      NaN          NaN
# Adani Brahma Samsara Vilasa                    NaN          NaN
# Sobha City                                     NaN          NaN
# Signature Global City 93                       NaN          NaN
#
#                              Sector 84 Road  Skyview Corporate Park
# PropertyName
# Smartworld One DXP                      NaN                     NaN
# M3M Crown                               NaN                     NaN
# Adani Brahma Samsara Vilasa             NaN                     NaN
# Sobha City                              NaN                     NaN
# Signature Global City 93                NaN                     NaN
#
# [5 rows x 1068 columns]

# %%
location_df = location_df.dropna(axis=1, how='all')
location_df = location_df.select_dtypes(exclude=['object'])

# %%
# THIS MATRIX IS SHOWING DISTANCE BETWEEN PROPERTY AND NEAREST LANDMARK. SO WE CANT REPLACE NAN WITH 0 BECAUSE IT WOULD BE INTERPRETED
# AS THE PROPERTY AND ITS LANDAMRK ARE SIDE BY SIDE (DISTANCE IS 0).
# NOW SINCE WE HAVE NO DATA AND THUS THESE NANS WONT BE INCLUDED IN OUR RECOMMENDER SYSTEM SO MIGHT AS WELL FILL IT WITH THE HIGHEST VALUE IN THE MATRIX TO SUGGEST THAT THESE LANDMARKS ARE FAR
# AWAY FROM THE PROPERTIES 

location_df.fillna(54000, inplace=True)

# %%
location_df
# Out:
#                              Bajghera Road  Palam Vihar Halt  \
# PropertyName
# Smartworld One DXP                   800.0            2500.0
# M3M Crown                            550.0           54000.0
# Adani Brahma Samsara Vilasa         5300.0           54000.0
# Sobha City                          1500.0           54000.0
# Signature Global City 93           54000.0           54000.0
# ...                                    ...               ...
# DLF Princeton Estate               54000.0           54000.0
# Pyramid Urban Homes 2              54000.0           54000.0
# Satya The Hermitage                54000.0           54000.0
# BPTP Spacio                        54000.0           54000.0
# SS The Coralwood                   54000.0           54000.0
#
#                              DPSG Palam Vihar  Park Hospital  \
# PropertyName
# Smartworld One DXP                     3100.0         3100.0
# M3M Crown                             54000.0        54000.0
# Adani Brahma Samsara Vilasa           54000.0        54000.0
# Sobha City                            54000.0        54000.0
# Signature Global City 93              54000.0         5500.0
# ...                                       ...            ...
# DLF Princeton Estate                  54000.0        54000.0
# Pyramid Urban Homes 2                 54000.0        54000.0
# Satya The Hermitage                   54000.0        54000.0
# BPTP Spacio                           54000.0        54000.0
# SS The Coralwood                      54000.0        54000.0
#
#                              Gurgaon Railway Station  The NorthCap University  \
# PropertyName
# Smartworld One DXP                            4900.0                   5400.0
# M3M Crown                                    54000.0                   6700.0
# Adani Brahma Samsara Vilasa                   2500.0                   8800.0
# Sobha City                                    6500.0                   6700.0
# Signature Global City 93                     54000.0                  54000.0
# ...                                              ...                      ...
# DLF Princeton Estate                         54000.0                  54000.0
# Pyramid Urban Homes 2                        54000.0                  54000.0
# Satya The Hermitage                          54000.0                  54000.0
# BPTP Spacio                                  54000.0                  54000.0
# SS The Coralwood                             54000.0                  54000.0
#
#                              Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# PropertyName
# Smartworld One DXP                1200.0                           7700.0
# M3M Crown                         3800.0                          54000.0
# Adani Brahma Samsara Vilasa      54000.0                          54000.0
# Sobha City                        5100.0                          54000.0
# Signature Global City 93         54000.0                          54000.0
# ...                                  ...                              ...
# DLF Princeton Estate             54000.0                          54000.0
# Pyramid Urban Homes 2            54000.0                          54000.0
# Satya The Hermitage              54000.0                          54000.0
# BPTP Spacio                      54000.0                          54000.0
# SS The Coralwood                 54000.0                          54000.0
#
#                              Dwarka Sector 21, Metro Station  \
# PropertyName
# Smartworld One DXP                                    7200.0
# M3M Crown                                            54000.0
# Adani Brahma Samsara Vilasa                          54000.0
# Sobha City                                           54000.0
# Signature Global City 93                             54000.0
# ...                                                      ...
# DLF Princeton Estate                                 54000.0
# Pyramid Urban Homes 2                                54000.0
# Satya The Hermitage                                  54000.0
# BPTP Spacio                                          54000.0
# SS The Coralwood                                     54000.0
#
#                              Pacific D21 Mall  ...  \
# PropertyName                                   ...
# Smartworld One DXP                     7400.0  ...
# M3M Crown                              7500.0  ...
# Adani Brahma Samsara Vilasa           54000.0  ...
# Sobha City                             8200.0  ...
# Signature Global City 93              54000.0  ...
# ...                                       ...  ...
# DLF Princeton Estate                  54000.0  ...
# Pyramid Urban Homes 2                 54000.0  ...
# Satya The Hermitage                   54000.0  ...
# BPTP Spacio                           54000.0  ...
# SS The Coralwood                      54000.0  ...
#
#                              Delhi Public School Gurugram Sector 67A  \
# PropertyName
# Smartworld One DXP                                           54000.0
# M3M Crown                                                    54000.0
# Adani Brahma Samsara Vilasa                                  54000.0
# Sobha City                                                   54000.0
# Signature Global City 93                                     54000.0
# ...                                                              ...
# DLF Princeton Estate                                         54000.0
# Pyramid Urban Homes 2                                        54000.0
# Satya The Hermitage                                          54000.0
# BPTP Spacio                                                  54000.0
# SS The Coralwood                                             54000.0
#
#                              Samrat Mihir Bhoj Road  \
# PropertyName
# Smartworld One DXP                          54000.0
# M3M Crown                                   54000.0
# Adani Brahma Samsara Vilasa                 54000.0
# Sobha City                                  54000.0
# Signature Global City 93                    54000.0
# ...                                             ...
# DLF Princeton Estate                        54000.0
# Pyramid Urban Homes 2                       54000.0
# Satya The Hermitage                         54000.0
# BPTP Spacio                                 54000.0
# SS The Coralwood                            54000.0
#
#                              The Shri Ram School Aravali  \
# PropertyName
# Smartworld One DXP                               54000.0
# M3M Crown                                        54000.0
# Adani Brahma Samsara Vilasa                      54000.0
# Sobha City                                       54000.0
# Signature Global City 93                         54000.0
# ...                                                  ...
# DLF Princeton Estate                             54000.0
# Pyramid Urban Homes 2                            54000.0
# Satya The Hermitage                              54000.0
# BPTP Spacio                                      54000.0
# SS The Coralwood                                 54000.0
#
#                              Taj City Centre Gurugram  \
# PropertyName
# Smartworld One DXP                            54000.0
# M3M Crown                                     54000.0
# Adani Brahma Samsara Vilasa                   54000.0
# Sobha City                                    54000.0
# Signature Global City 93                      54000.0
# ...                                               ...
# DLF Princeton Estate                          54000.0
# Pyramid Urban Homes 2                         54000.0
# Satya The Hermitage                           54000.0
# BPTP Spacio                                   54000.0
# SS The Coralwood                              54000.0
#
#                              Minda Industries  Corporate Office  \
# PropertyName
# Smartworld One DXP                                      54000.0
# M3M Crown                                               54000.0
# Adani Brahma Samsara Vilasa                             54000.0
# Sobha City                                              54000.0
# Signature Global City 93                                54000.0
# ...                                                         ...
# DLF Princeton Estate                                    54000.0
# Pyramid Urban Homes 2                                   54000.0
# Satya The Hermitage                                     54000.0
# BPTP Spacio                                             54000.0
# SS The Coralwood                                        54000.0
#
#                              Rampura Flyover, Naurangpur Rd  \
# PropertyName
# Smartworld One DXP                                  54000.0
# M3M Crown                                           54000.0
# Adani Brahma Samsara Vilasa                         54000.0
# Sobha City                                          54000.0
# Signature Global City 93                            54000.0
# ...                                                     ...
# DLF Princeton Estate                                54000.0
# Pyramid Urban Homes 2                               54000.0
# Satya The Hermitage                                 54000.0
# BPTP Spacio                                         54000.0
# SS The Coralwood                                    54000.0
#
#                              Manesar toll plaza - Kherki Daula  \
# PropertyName
# Smartworld One DXP                                     54000.0
# M3M Crown                                              54000.0
# Adani Brahma Samsara Vilasa                            54000.0
# Sobha City                                             54000.0
# Signature Global City 93                               54000.0
# ...                                                        ...
# DLF Princeton Estate                                   54000.0
# Pyramid Urban Homes 2                                  54000.0
# Satya The Hermitage                                    54000.0
# BPTP Spacio                                            54000.0
# SS The Coralwood                                       54000.0
#
#                              Imt Manesar, Gurugram  Sector 84 Road  \
# PropertyName
# Smartworld One DXP                         54000.0         54000.0
# M3M Crown                                  54000.0         54000.0
# Adani Brahma Samsara Vilasa                54000.0         54000.0
# Sobha City                                 54000.0         54000.0
# Signature Global City 93                   54000.0         54000.0
# ...                                            ...             ...
# DLF Princeton Estate                       54000.0         54000.0
# Pyramid Urban Homes 2                      54000.0         54000.0
# Satya The Hermitage                        54000.0         54000.0
# BPTP Spacio                                54000.0         54000.0
# SS The Coralwood                           54000.0         54000.0
#
#                              Skyview Corporate Park
# PropertyName
# Smartworld One DXP                          54000.0
# M3M Crown                                   54000.0
# Adani Brahma Samsara Vilasa                 54000.0
# Sobha City                                  54000.0
# Signature Global City 93                    54000.0
# ...                                             ...
# DLF Princeton Estate                        54000.0
# Pyramid Urban Homes 2                       54000.0
# Satya The Hermitage                         54000.0
# BPTP Spacio                                 54000.0
# SS The Coralwood                            54000.0
#
# [246 rows x 809 columns]

# %%
# LETS SCALE THE DATAFRAME
scaler.set_output(transform="pandas")
scaled_df2 = scaler.fit_transform(location_df)

# %%
scaled_df2
# Out:
#                              Bajghera Road  Palam Vihar Halt  \
# PropertyName
# Smartworld One DXP               -7.960979        -15.652476
# M3M Crown                        -7.998993          0.063888
# Adani Brahma Samsara Vilasa      -7.276720          0.063888
# Sobha City                       -7.854539          0.063888
# Signature Global City 93          0.128476          0.063888
# ...                                    ...               ...
# DLF Princeton Estate              0.128476          0.063888
# Pyramid Urban Homes 2             0.128476          0.063888
# Satya The Hermitage               0.128476          0.063888
# BPTP Spacio                       0.128476          0.063888
# SS The Coralwood                  0.128476          0.063888
#
#                              DPSG Palam Vihar  Park Hospital  \
# PropertyName
# Smartworld One DXP                 -15.652476      -3.149592
# M3M Crown                            0.063888       0.328277
# Adani Brahma Samsara Vilasa          0.063888       0.328277
# Sobha City                           0.063888       0.328277
# Signature Global City 93             0.063888      -2.985606
# ...                                       ...            ...
# DLF Princeton Estate                 0.063888       0.328277
# Pyramid Urban Homes 2                0.063888       0.328277
# Satya The Hermitage                  0.063888       0.328277
# BPTP Spacio                          0.063888       0.328277
# SS The Coralwood                     0.063888       0.328277
#
#                              Gurgaon Railway Station  The NorthCap University  \
# PropertyName
# Smartworld One DXP                         -2.966108                -3.147217
# M3M Crown                                   0.368941                -3.054053
# Adani Brahma Samsara Vilasa                -3.129124                -2.903557
# Sobha City                                 -2.857430                -3.054053
# Signature Global City 93                    0.368941                 0.335688
# ...                                              ...                      ...
# DLF Princeton Estate                        0.368941                 0.335688
# Pyramid Urban Homes 2                       0.368941                 0.335688
# Satya The Hermitage                         0.368941                 0.335688
# BPTP Spacio                                 0.368941                 0.335688
# SS The Coralwood                            0.368941                 0.335688
#
#                              Dwarka Expy  Hyatt Place Gurgaon Udyog Vihar  \
# PropertyName
# Smartworld One DXP             -3.726615                       -10.231739
# M3M Crown                      -3.529275                         0.090308
# Adani Brahma Samsara Vilasa     0.280891                         0.090308
# Sobha City                     -3.430606                         0.090308
# Signature Global City 93        0.280891                         0.090308
# ...                                  ...                              ...
# DLF Princeton Estate            0.280891                         0.090308
# Pyramid Urban Homes 2           0.280891                         0.090308
# Satya The Hermitage             0.280891                         0.090308
# BPTP Spacio                     0.280891                         0.090308
# SS The Coralwood                0.280891                         0.090308
#
#                              Dwarka Sector 21, Metro Station  \
# PropertyName
# Smartworld One DXP                                -15.652476
# M3M Crown                                           0.063888
# Adani Brahma Samsara Vilasa                         0.063888
# Sobha City                                          0.063888
# Signature Global City 93                            0.063888
# ...                                                      ...
# DLF Princeton Estate                                0.063888
# Pyramid Urban Homes 2                               0.063888
# Satya The Hermitage                                 0.063888
# BPTP Spacio                                         0.063888
# SS The Coralwood                                    0.063888
#
#                              Pacific D21 Mall  ...  \
# PropertyName                                   ...
# Smartworld One DXP                  -6.023233  ...
# M3M Crown                           -6.009941  ...
# Adani Brahma Samsara Vilasa          0.171073  ...
# Sobha City                          -5.916893  ...
# Signature Global City 93             0.171073  ...
# ...                                       ...  ...
# DLF Princeton Estate                 0.171073  ...
# Pyramid Urban Homes 2                0.171073  ...
# Satya The Hermitage                  0.171073  ...
# BPTP Spacio                          0.171073  ...
# SS The Coralwood                     0.171073  ...
#
#                              Delhi Public School Gurugram Sector 67A  \
# PropertyName
# Smartworld One DXP                                          0.063888
# M3M Crown                                                   0.063888
# Adani Brahma Samsara Vilasa                                 0.063888
# Sobha City                                                  0.063888
# Signature Global City 93                                    0.063888
# ...                                                              ...
# DLF Princeton Estate                                        0.063888
# Pyramid Urban Homes 2                                       0.063888
# Satya The Hermitage                                         0.063888
# BPTP Spacio                                                 0.063888
# SS The Coralwood                                            0.063888
#
#                              Samrat Mihir Bhoj Road  \
# PropertyName
# Smartworld One DXP                         0.063888
# M3M Crown                                  0.063888
# Adani Brahma Samsara Vilasa                0.063888
# Sobha City                                 0.063888
# Signature Global City 93                   0.063888
# ...                                             ...
# DLF Princeton Estate                       0.063888
# Pyramid Urban Homes 2                      0.063888
# Satya The Hermitage                        0.063888
# BPTP Spacio                                0.063888
# SS The Coralwood                           0.063888
#
#                              The Shri Ram School Aravali  \
# PropertyName
# Smartworld One DXP                              0.063888
# M3M Crown                                       0.063888
# Adani Brahma Samsara Vilasa                     0.063888
# Sobha City                                      0.063888
# Signature Global City 93                        0.063888
# ...                                                  ...
# DLF Princeton Estate                            0.063888
# Pyramid Urban Homes 2                           0.063888
# Satya The Hermitage                             0.063888
# BPTP Spacio                                     0.063888
# SS The Coralwood                                0.063888
#
#                              Taj City Centre Gurugram  \
# PropertyName
# Smartworld One DXP                           0.063888
# M3M Crown                                    0.063888
# Adani Brahma Samsara Vilasa                  0.063888
# Sobha City                                   0.063888
# Signature Global City 93                     0.063888
# ...                                               ...
# DLF Princeton Estate                         0.063888
# Pyramid Urban Homes 2                        0.063888
# Satya The Hermitage                          0.063888
# BPTP Spacio                                  0.063888
# SS The Coralwood                             0.063888
#
#                              Minda Industries  Corporate Office  \
# PropertyName
# Smartworld One DXP                                     0.063888
# M3M Crown                                              0.063888
# Adani Brahma Samsara Vilasa                            0.063888
# Sobha City                                             0.063888
# Signature Global City 93                               0.063888
# ...                                                         ...
# DLF Princeton Estate                                   0.063888
# Pyramid Urban Homes 2                                  0.063888
# Satya The Hermitage                                    0.063888
# BPTP Spacio                                            0.063888
# SS The Coralwood                                       0.063888
#
#                              Rampura Flyover, Naurangpur Rd  \
# PropertyName
# Smartworld One DXP                                 0.063888
# M3M Crown                                          0.063888
# Adani Brahma Samsara Vilasa                        0.063888
# Sobha City                                         0.063888
# Signature Global City 93                           0.063888
# ...                                                     ...
# DLF Princeton Estate                               0.063888
# Pyramid Urban Homes 2                              0.063888
# Satya The Hermitage                                0.063888
# BPTP Spacio                                        0.063888
# SS The Coralwood                                   0.063888
#
#                              Manesar toll plaza - Kherki Daula  \
# PropertyName
# Smartworld One DXP                                    0.063888
# M3M Crown                                             0.063888
# Adani Brahma Samsara Vilasa                           0.063888
# Sobha City                                            0.063888
# Signature Global City 93                              0.063888
# ...                                                        ...
# DLF Princeton Estate                                  0.063888
# Pyramid Urban Homes 2                                 0.063888
# Satya The Hermitage                                   0.063888
# BPTP Spacio                                           0.063888
# SS The Coralwood                                      0.063888
#
#                              Imt Manesar, Gurugram  Sector 84 Road  \
# PropertyName
# Smartworld One DXP                        0.063888        0.063888
# M3M Crown                                 0.063888        0.063888
# Adani Brahma Samsara Vilasa               0.063888        0.063888
# Sobha City                                0.063888        0.063888
# Signature Global City 93                  0.063888        0.063888
# ...                                            ...             ...
# DLF Princeton Estate                      0.063888        0.063888
# Pyramid Urban Homes 2                     0.063888        0.063888
# Satya The Hermitage                       0.063888        0.063888
# BPTP Spacio                               0.063888        0.063888
# SS The Coralwood                          0.063888        0.063888
#
#                              Skyview Corporate Park
# PropertyName
# Smartworld One DXP                         0.063888
# M3M Crown                                  0.063888
# Adani Brahma Samsara Vilasa                0.063888
# Sobha City                                 0.063888
# Signature Global City 93                   0.063888
# ...                                             ...
# DLF Princeton Estate                       0.063888
# Pyramid Urban Homes 2                      0.063888
# Satya The Hermitage                        0.063888
# BPTP Spacio                                0.063888
# SS The Coralwood                           0.063888
#
# [246 rows x 809 columns]

# %%
cosinse_sim3 = cosine_similarity(scaled_df2)

# %%
def recommend_properties_with_scores2(property_name, top_n=5):
    cosine_sim_matrix = 2*cosinse_sim + 4*cosinse_sim2 + 1*cosinse_sim3
    
    property_idx = scaled_df2.index.get_loc(property_name)
    scores = list(enumerate(cosine_sim_matrix[property_idx]))
    sorted_scores = sorted(scores, key=lambda x: x[1], reverse=True)
    top_indices = [i[0] for i in sorted_scores[1:top_n+1]]
    top_scores = [i[1] for i in sorted_scores[1:top_n+1]]
    top_properties = scaled_df2.index[top_indices].tolist()
    
    new_recommendations_df = pd.DataFrame({
        'PropertyName': top_properties,
        'SimilarityScore': top_scores
    })
    
    return new_recommendations_df

recommend_properties_with_scores2('DLF The Camellias')
# Out:
#              PropertyName  SimilarityScore
# 0     Salcon The Verandas         3.994653
# 1       DLF The Magnolias         2.923290
# 2         DLF The Aralias         2.734712
# 3       Parsvnath Exotica         2.016697
# 4  Pioneer Urban Presidia         1.636074

# %% [markdown]
# Now we have three individual recommender systems based on Top facilities, Price details and Location Advantage having 3 individual cosine_similarity matrices. We can combine these three recommendation systems into one recommender system. In this recommender system we can assign weights to each matrix representing what will influence the recommender system more. For example if the cosine matrix of recommender system 3 has the highest weight, the overall recommender system will be more influenced by the the Location Advantage.

# %%
import pickle

pickle.dump(location_df, open("/Users/siddhant/housepriceproject/Capstone/datasets/locationdf.pkl", "wb"))

# %%
pickle.dump(cosinse_sim, open("/Users/siddhant/housepriceproject/Capstone/datasets/cosinse_sim.pkl", "wb"))
pickle.dump(cosinse_sim2, open("/Users/siddhant/housepriceproject/Capstone/datasets/cosinse_sim2.pkl", "wb"))
pickle.dump(cosinse_sim3, open("/Users/siddhant/housepriceproject/Capstone/datasets/cosinse_sim3.pkl", "wb"))

# %%
# Out:
# No properties found within 1 km.

# %%
# Out:
# Bajghera Road                          550.0
# Palam Vihar Halt                     54000.0
# DPSG Palam Vihar                     54000.0
# Park Hospital                        54000.0
# Gurgaon Railway Station              54000.0
#                                       ...
# Rampura Flyover, Naurangpur Rd       54000.0
# Manesar toll plaza - Kherki Daula    54000.0
# Imt Manesar, Gurugram                54000.0
# Sector 84 Road                       54000.0
# Skyview Corporate Park               54000.0
# Name: M3M Crown, Length: 809, dtype: float64
